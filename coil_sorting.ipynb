# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("data/ANN 재공현황.xlsx")
data.head()
# Out:
#    BUS_CD       COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 0  1173DK  07KC1022111A  2007KC1022   07KC1022111   92311302  07KC1022111
# 1  1173DK  07KC1022211A  2007KC1022   07KC1022211   92311302  07KC1022211
# 2  1173DK  07KC1022311A  2007KC1022   07KC1022311   92311302  07KC1022311
# 3  1173DK   07KK1D22111  2007KK1D22   07KK1D22111  HAT052900          NaN
# 4  1173DK   09KA1B77311  2009KA1B77   09KA1B77311  HAN026620          NaN
#
#    TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...              CRT_DT CRTCHR_NO  \
# 0     NaN  1282N       NaN    NaN  ... 2007-03-06 00:00:00    MGTEST
# 1     NaN  1282N       NaN    NaN  ... 2007-03-07 00:00:00    MGTEST
# 2     NaN  1282N       NaN    NaN  ... 2007-03-07 00:00:00    MGTEST
# 3     NaN    NaN       NaN    NaN  ... 2011-09-29 09:14:46       강연철
# 4     NaN  1282N       NaN    NaN  ... 2010-01-01 00:00:00    MGTEST
#
#                UPD_DT UPDCHR_NO COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD  \
# ...

# %%
# 수정자
data.drop("UPDCHR_NO", axis = 1, inplace=True)
# 생성자 
data.drop("CRTCHR_NO", axis = 1, inplace=True)

# %% [markdown]
# ### 규격

# %%
PRDSPC_ID_unique = data["PRDSPC_ID"].unique()
PRDSPC_ID_unique
# Out:
# array(['SCP1-H-B', 'S45CM-S', '50CRV4M-S', 'S55CM-R', 'SK5M-S', 'S35CM-R',
#        'S55CM-S', 'S20CM-R', 'SCP1-S-B', '50CRV4M-R', 'DK800',
#        'SAE1070M-R', 'S45C-PA', 'SAE1552M-R', '16MNCR5M-S', 'SAE1055M-R',
#        'CK75M2', 'SK85', 'SK85M-S', 'S20CM-S', 'S15CM-S', 'S70CM-AD',
#        'SAE1074M-R', '16MNCR5M2', 'S45CM-R', 'S50CM-S', 'CK75M3',
#        'SAE1045M-S', 'C80M', 'SK4M-S', 'SK85M-R', 'SK5M-R', 'SK4M-R',
#        'H800LA', 'SAE1020', 'SPCC-1BP', 'SAE1010H', 'SPCC-2B',
#        'SCP1-1/2H-B', '51CRV4M-S', 'SAE1050M-R', 'C67S', 'SNCM220M-S',
#        'SNCM220-PA', 'S35CM-S', 'C75S-HT', 'SK85M', 'SCM430M-S',
#        'SAE1010M-R', 'SAE1070M-S', '100CR6'], dtype=object)

# %% [markdown]
# ## 특별 CYCLE 규격

# %%
special_cycle_code = np.array(["DK800","S700MC","H800LA","S55C-PA","S45CM-R","SAE1050-PA","SAE1050M-A",
                                "SK2M-R(PPC)","SK4M-R(PPC)","SK5M-R(PPC)","SK4M-R","SK5M-R","SKS51M-R",
                                "SKS81M-R","SAE1074M-R","S55CM-S","SCM435M-S","SK5M-S""51CRV4M-S","CK75M2",
                                "CK75M3","C80M","SK강","SK85","100CR6","100CR6-PA","SUJ2","SAE52100","AISI4140M-S","50CRV4M-S","S45CM-R"])

# %% [markdown]
# ## 일반 CYCLE 규격

# %%
general_cycle_code = np.setdiff1d(PRDSPC_ID_unique, special_cycle_code)
general_cycle_code
# Out:
# array(['16MNCR5M-S', '16MNCR5M2', '50CRV4M-R', '51CRV4M-S', 'C67S',
#        'C75S-HT', 'S15CM-S', 'S20CM-R', 'S20CM-S', 'S35CM-R', 'S35CM-S',
#        'S45C-PA', 'S45CM-S', 'S50CM-S', 'S55CM-R', 'S70CM-AD', 'SAE1010H',
#        'SAE1010M-R', 'SAE1020', 'SAE1045M-S', 'SAE1050M-R', 'SAE1055M-R',
#        'SAE1070M-R', 'SAE1070M-S', 'SAE1552M-R', 'SCM430M-S',
#        'SCP1-1/2H-B', 'SCP1-H-B', 'SCP1-S-B', 'SK4M-S', 'SK5M-S', 'SK85M',
#        'SK85M-R', 'SK85M-S', 'SNCM220-PA', 'SNCM220M-S', 'SPCC-1BP',
#        'SPCC-2B'], dtype=object)

# %% [markdown]
# ## DYNAX CORP.

# %%
DYNAX_CORP = np.array(["S55C-PA"])

# %%
DYNAX_CORP_data = data[data["PRDSPC_ID"] == DYNAX_CORP[0]]
DYNAX_CORP_data.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## 한국보그워너티에스
# ### ANN1차 620

# %%
HKBOG = np.array(["S45CM-R"])

# %%
HKBOG_data = data[data["PRDSPC_ID"] == HKBOG[0]]
HKBOG_data.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 77  1173DK  22G122021111A  2022G12202   22G12202111  CRW397701  22G12202111
# 78  1173DK  22G122021121A  2022G12202   22G12202112  CTX443601  22G12202112
# 79  1173DK  22G122022111A  2022G12202   22G12202211  CRW397701  22G12202111
# 80  1173DK  22G122022121A  2022G12202   22G12202212  CTX443601  22G12202112
# 81  1173DK  22G122023111A  2022G12202   22G12202311  CRW397701  22G12202111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 77   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 78   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 79   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 80   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 81   103.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
#
# ...

# %% [markdown]
# ### ANN 0차

# %%
HKBOG_data_ANN0 = HKBOG_data[HKBOG_data["PNSPRC_CD"] == "AN10"]
HKBOG_data_ANN0.head()
# Out:
# Empty DataFrame
# ...

# %%
HKBOG_data_ANN0_size = len(HKBOG_data_ANN0)
HKBOG_data_ANN0_size
# Out:
# 0

# %% [markdown]
# ### ANN 1차 이상

# %%
HKBOG_data_ANN1 = HKBOG_data[HKBOG_data["PNSPRC_CD"] != "AN10"]
HKBOG_data_ANN1.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 77  1173DK  22G122021111A  2022G12202   22G12202111  CRW397701  22G12202111
# 78  1173DK  22G122021121A  2022G12202   22G12202112  CTX443601  22G12202112
# 79  1173DK  22G122022111A  2022G12202   22G12202211  CRW397701  22G12202111
# 80  1173DK  22G122022121A  2022G12202   22G12202212  CTX443601  22G12202112
# 81  1173DK  22G122023111A  2022G12202   22G12202311  CRW397701  22G12202111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 77   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 78   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 79   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 80   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 81   103.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
#
# ...

# %%
HKBOG_data_ANN1_size = len(HKBOG_data_ANN1)
HKBOG_data_ANN1_size
# Out:
# 6

# %% [markdown]
# ## (주)지에스앤티

# %%
GSNT = np.array(["SAE1050-PA","SAE1050M-A"])

# %%
GSNT_data = data[(data["PRDSPC_ID"] == GSNT[0]) | (data["PRDSPC_ID"] == GSNT[1])]
GSNT_data.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## 일진엔티에스(주)

# %% [markdown]
# ### 일진엔티에스1 : 625 , 625

# %%
ILJINNTS_1 = np.array(["SK2M-R(PPC)","SK4M-R(PPC)","SK5M-R(PPC)"])

# %%
ILJINNTS_1_data = data[(data["PRDSPC_ID"] == ILJINNTS_1[0]) |(data["PRDSPC_ID"] == ILJINNTS_1[1]) | (data["PRDSPC_ID"] == ILJINNTS_1[2]) ]
len(ILJINNTS_1_data)
# Out:
# 0

# %% [markdown]
# ### 일진엔티에스2 : 750, 700(표준)

# %%
ILJINNTS_2 = np.array(["SK4M-R","SK5M-R","SKS51M-R","SKS81M-R"])

# %%
ILJINNTS_2_data = data[(data["PRDSPC_ID"] == ILJINNTS_2[0]) |(data["PRDSPC_ID"] == ILJINNTS_2[1]) | (data["PRDSPC_ID"] == ILJINNTS_2[2]) | (data["PRDSPC_ID"] == ILJINNTS_2[3]) ]
len(ILJINNTS_2_data)
# Out:
# 4

# %% [markdown]
# ###  PNSPRC_CD : 현공정코드
# - AN10 : ANN 0차
# - AN11 : ANN 1차
# - AN12 : ANN 2차
# - AN13 : ANN 3차

# %% [markdown]
# ### ANN0차

# %%
ILJINNTS_2_data_ANN0 = ILJINNTS_2_data[ILJINNTS_2_data["PNSPRC_CD"] == "AN10"]
ILJINNTS_2_data_ANN0
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 361  1173DK  22H130252111A  2022H13025   22H13025211  HBF072770  22H13025111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 361   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-02 04:54:38
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 361 2022-09-05 15:46:06        NaT        NaN        NaN  1055A         L
#
#      ZON_CD
# 361   1510P
#
# [1 rows x 113 columns]

# %%
ILJINNTS_2_data_ANN0_size = len(ILJINNTS_2_data_ANN0)
ILJINNTS_2_data_ANN0_size
# Out:
# 1

# %% [markdown]
# ### ANN1차이상

# %%
ILJINNTS_2_data_ANN1 = ILJINNTS_2_data[ILJINNTS_2_data["PNSPRC_CD"] != "AN10"]
ILJINNTS_2_data_ANN1.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 132  1173DK  22G13050111  2022G13050   22G13050111  HBF162820  22G13050111
# 133  1173DK  22G13053111  2022G13053   22G13053111  HBF162720  22G13053111
# 364  1173DK  22H13032111  2022H13032   22H13032111  HBF072850  22H13032111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 132     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-25 13:28:39
# 133     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-27 10:21:28
# 364     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-17 09:32:07
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 132 2022-09-15 02:46:12        NaT        NaN        NaN  1055A         E
# 133 2022-09-15 01:26:57        NaT        NaN        NaN  1055B         E
# 364 2022-09-03 08:55:11        NaT        NaN        NaN  1055C         E
#
#      ZON_CD
# 132   1510P
# 133   1510P
# 364   1510P
# ...

# %%
ILJINNTS_2_data_ANN1_size = len(ILJINNTS_2_data_ANN1)
ILJINNTS_2_data_ANN1_size
# Out:
# 3

# %% [markdown]
# ## JMI

# %%
JMI = np.array(["SAE1074M-R"])

# %%
JMI_data = data[data["PRDSPC_ID"] == JMI[0]]
JMI_data
# Out:
#     BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 63  1173DK  22G12107111  2022G12107   22G12107111  HBZ078470  22G12107111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 63     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-11 17:07:37
#
#                 UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 63 2022-09-05 12:55:33        NaT        NaN        NaN  1055A         E
#
#     ZON_CD
# 63   1510P
#
# [1 rows x 113 columns]

# %% [markdown]
# ### ANN 0차

# %%
JMI_data_ANN0 = JMI_data[JMI_data["PNSPRC_CD"] == "AN10"]
JMI_data_ANN0.head()
# Out:
#     BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 63  1173DK  22G12107111  2022G12107   22G12107111  HBZ078470  22G12107111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 63     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-11 17:07:37
#
#                 UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 63 2022-09-05 12:55:33        NaT        NaN        NaN  1055A         E
#
#     ZON_CD
# 63   1510P
#
# [1 rows x 113 columns]

# %%
JMI_data_ANN0_size = len(JMI_data_ANN0)
JMI_data_ANN0_size
# Out:
# 1

# %% [markdown]
# ### ANN 1차 이상

# %%
JMI_data_ANN1 = JMI_data[JMI_data["PNSPRC_CD"] != "AN10"]
JMI_data_ANN1.head()
# Out:
# Empty DataFrame
# ...

# %%
JMI_data_ANN1_size = len(JMI_data_ANN1)
JMI_data_ANN1_size
# Out:
# 0

# %% [markdown]
# ## (주)정민스틸 / (주)대성파인텍 / 지에스앤티 / (주)화진금속

# %%
JM_DS_GS_HJ = np.array(["S55CM-S","SCM435M-S","SK5M-S"])

# %%
JM_DS_GS_HJ_data = data[(data["PRDSPC_ID"] == JM_DS_GS_HJ[0])| (data["PRDSPC_ID"] == JM_DS_GS_HJ[1]) | (data["PRDSPC_ID"] == JM_DS_GS_HJ[2]) ]
JM_DS_GS_HJ_data.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 10  1173DK    22A13B70111  2022A13B70   22A13B70111   HBZ051210          NaN
# 20  1173DK    22C13B65111  2022C13B65   22C13B65111  HBA055140A  22C13B65111
# 21  1173DK    22C13B73112  2022C13B73   22C13B73112   HBB097230  22C13B73112
# 22  1173DK    22C13C62111  2022C13C62   22C13C62111  HBY131730A  22C13C62111
# 23  1173DK  22D12E321121A  2022D12E32   22D12E32112  HBC099530C  22D12E32112
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 10     NaN  1282N     1282N    NaN  ...   1065A       0 2022-03-08 13:35:00
# 20     1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-23 16:34:45
# 21     1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-29 10:27:44
# 22     1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-07 09:12:23
# 23     1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-14 21:51:42
#
# ...

# %% [markdown]
# ### ANN 0차

# %%
JM_DS_GS_HJ_data_ANN0 = JM_DS_GS_HJ_data[JM_DS_GS_HJ_data["PNSPRC_CD"] == "AN10"]
JM_DS_GS_HJ_data_ANN0.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 23   1173DK  22D12E321121A  2022D12E32   22D12E32112  HBC099530C  22D12E32112
# 362  1173DK    22H13026111  2022H13026   22H13026111    CPW58330  22H13026111
# 365  1173DK    22H13041111  2022H13041   22H13041111    CTW45530  22H13041111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 23      1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-14 21:51:42
# 362     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-16 15:51:50
# 365     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-23 14:09:06
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 23  2022-09-14 19:23:53        NaT        NaN        NaN  1055A         E
# 362 2022-09-04 09:25:47        NaT        NaN        NaN  1055A         L
# 365 2022-09-03 10:19:40        NaT        NaN        NaN  1055A         E
#
#      ZON_CD
# 23    1510P
# 362   1510P
# ...

# %%
JM_DS_GS_HJ_data_ANN0_size = len(JM_DS_GS_HJ_data_ANN0)
JM_DS_GS_HJ_data_ANN0_size
# Out:
# 3

# %% [markdown]
# ### ANN 1차 이상

# %%
JM_DS_GS_HJ_data_ANN1 = JM_DS_GS_HJ_data[JM_DS_GS_HJ_data["PNSPRC_CD"] != "AN10"]
JM_DS_GS_HJ_data_ANN1.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO  \
# 10  1173DK    22A13B70111  2022A13B70   22A13B70111   HBZ051210
# 20  1173DK    22C13B65111  2022C13B65   22C13B65111  HBA055140A
# 21  1173DK    22C13B73112  2022C13B73   22C13B73112   HBB097230
# 22  1173DK    22C13C62111  2022C13C62   22C13C62111  HBY131730A
# 51  1173DK  22F130591111A  2022F13059   22F13059111    CRX30820
#
#         MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 10            NaN     NaN  1282N     1282N    NaN  ...   1065A       0
# 20    22C13B65111     1.0  1282N     1282N    NaN  ...   1065A       0
# 21    22C13B73112     1.0  1282N     1282N    NaN  ...   1065A       0
# 22    22C13C62111     1.0  1282N     1282N    NaN  ...   1065A       0
# 51  22F130591111A   101.0  1282N     1282N    NaN  ...   1065A       0
#
#                 CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %%
JM_DS_GS_HJ_data_ANN1_size = len(JM_DS_GS_HJ_data_ANN1)
JM_DS_GS_HJ_data_ANN1_size
# Out:
# 25

# %% [markdown]
# ## NHK / NHK SPRING PREC / NHK SPRING(THA~)

# %%
NHK = np.array(["51CRV4M-S"])

# %%
NHK_data = data[data["PRDSPC_ID"] == NHK[0]]
NHK_data.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO  \
# 233  1173DK  22H120342111A  2022H12034   22H12034211  HBF137390
# 235  1173DK  22H120391111A  2022H12039   22H12039111  HBF137220
# 236  1173DK  22H120392111A  2022H12039   22H12039211  HBF137220
# 237  1173DK  22H120411111A  2022H12041   22H12041111  HBF137210
# 238  1173DK  22H120412111A  2022H12041   22H12041211  HBF137210
#
#          MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 233  22H120342111A   102.0  1282N     1282N    NaN  ...   1065A       0
# 235  22H120391111A   101.0  1282N     1282N    NaN  ...   1065A       0
# 236  22H120392111A   102.0  1282N     1282N    NaN  ...   1065A       0
# 237  22H120411111A   101.0  1282N     1282N    NaN  ...   1065A       0
# 238  22H120412111A   102.0  1282N     1282N    NaN  ...   1065A       0
#
#                  CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %% [markdown]
# ### ANN 0차

# %%
NHK_data_ANN0 = NHK_data[NHK_data["PNSPRC_CD"] == "AN10"]
NHK_data_ANN0.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 312  1173DK  22H12187112  2022H12187   22H12187112  HBG167280  22H12187112
# 327  1173DK  22H12214111  2022H12214   22H12214111  HBG167210  22H12214111
# 328  1173DK  22H12214112  2022H12214   22H12214112  HBG167200  22H12214112
# 329  1173DK  22H12215111  2022H12215   22H12215111  HBG167070  22H12215111
# 330  1173DK  22H12216111  2022H12216   22H12216111  HBG167410  22H12216111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 312     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-23 13:12:35
# 327     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-25 09:50:57
# 328     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-25 09:50:57
# 329     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-25 09:52:28
# 330     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-25 09:53:38
#
# ...

# %%
NHK_data_ANN0_size = len(NHK_data_ANN0)
NHK_data_ANN0_size
# Out:
# 6

# %% [markdown]
# ### ANN 1차 이상

# %%
NHK_data_ANN1 = NHK_data[NHK_data["PNSPRC_CD"] != "AN10"]
NHK_data_ANN1.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO  \
# 233  1173DK  22H120342111A  2022H12034   22H12034211  HBF137390
# 235  1173DK  22H120391111A  2022H12039   22H12039111  HBF137220
# 236  1173DK  22H120392111A  2022H12039   22H12039211  HBF137220
# 237  1173DK  22H120411111A  2022H12041   22H12041111  HBF137210
# 238  1173DK  22H120412111A  2022H12041   22H12041211  HBF137210
#
#          MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 233  22H120342111A   102.0  1282N     1282N    NaN  ...   1065A       0
# 235  22H120391111A   101.0  1282N     1282N    NaN  ...   1065A       0
# 236  22H120392111A   102.0  1282N     1282N    NaN  ...   1065A       0
# 237  22H120411111A   101.0  1282N     1282N    NaN  ...   1065A       0
# 238  22H120412111A   102.0  1282N     1282N    NaN  ...   1065A       0
#
#                  CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %%
NHK_data_ANN1_size = len(NHK_data_ANN1)
NHK_data_ANN1_size
# Out:
# 12

# %% [markdown]
# ## SCHAEFFLER GROUP

# %%
SCHAEFFLER = np.array(["CK75M2","CK75M3"])

# %%
SCHAEFFLER_data = data[(data["PRDSPC_ID"] == SCHAEFFLER[0]) | (data["PRDSPC_ID"] == SCHAEFFLER[1])]
SCHAEFFLER_data.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO  \
# 45  1173DK  22F12H421111A  2022F12H42   22F12H42111  HBE112120B
# 46  1173DK  22F12H421121A  2022F12H42   22F12H42112  HBE112120B
# 47  1173DK  22F12T391111A  2022F12T39   22F12T39111  HBE112450B
# 48  1173DK  22F12T391121A  2022F12T39   22F12T39112  HBE112450B
# 84  1173DK    22G12224111  2022G12224   22G12224111   HBE071430
#
#         MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 45  22F12H421111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 46  22F12H421121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 47  22F12T391111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 48  22F12T391121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 84    22G12224111     1.0  1282Y     1282Y    NaN  ...   1065A       0
#
#                 CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %% [markdown]
# ### ANN 0차

# %%
SCHAEFFLER_data_ANN0 = SCHAEFFLER_data[SCHAEFFLER_data["PNSPRC_CD"] == "AN10"]
SCHAEFFLER_data_ANN0.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 313  1173DK    22H12194111  2022H12194   22H12194111  HBG136070A  22H12194111
# 314  1173DK    22H12194112  2022H12194   22H12194112   HBG135920  22H12194112
# 315  1173DK  22H121951111A  2022H12195   22H12195111  HBG0882801  22H12195111
# 316  1173DK  22H121952111A  2022H12195   22H12195211  HBG0882801  22H12195111
# 317  1173DK  22H121953111A  2022H12195   22H12195311  HBG0882801  22H12195111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 313     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-23 14:28:29
# 314     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-23 14:28:29
# 315   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-04 12:03:37
# 316   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-04 12:03:37
# 317   103.0  1282N     1282N    NaN  ...   1065A       0 2022-09-04 12:03:37
#
# ...

# %%
SCHAEFFLER_data_ANN0_size = len(SCHAEFFLER_data_ANN0)
SCHAEFFLER_data_ANN0_size
# Out:
# 10

# %% [markdown]
# ### ANN 1차,2차

# %%
SCHAEFFLER_data_ANN12 = SCHAEFFLER_data[(SCHAEFFLER_data["PNSPRC_CD"] == "AN11") | (SCHAEFFLER_data["PNSPRC_CD"] == "AN12")]
SCHAEFFLER_data_ANN12.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO  \
# 45  1173DK  22F12H421111A  2022F12H42   22F12H42111  HBE112120B
# 46  1173DK  22F12H421121A  2022F12H42   22F12H42112  HBE112120B
# 47  1173DK  22F12T391111A  2022F12T39   22F12T39111  HBE112450B
# 48  1173DK  22F12T391121A  2022F12T39   22F12T39112  HBE112450B
# 84  1173DK    22G12224111  2022G12224   22G12224111   HBE071430
#
#         MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 45  22F12H421111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 46  22F12H421121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 47  22F12T391111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 48  22F12T391121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 84    22G12224111     1.0  1282Y     1282Y    NaN  ...   1065A       0
#
#                 CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %%
SCHAEFFLER_data_ANN12_size = len(SCHAEFFLER_data_ANN12)
SCHAEFFLER_data_ANN12_size
# Out:
# 39

# %% [markdown]
# ### ANN 3차

# %%
SCHAEFFLER_data_ANN3 = SCHAEFFLER_data[SCHAEFFLER_data["PNSPRC_CD"] == "AN13"]
SCHAEFFLER_data_ANN3.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## SCHAEFFLER GROUP / HARSHA ENGINEE / LUK / 나라엠앤디 /(주)대유단조

# %%
SCHA_HAR_LUK_NARA_DAEU = np.array(["C80M"])

# %%
SCHA_HAR_LUK_NARA_DAEU_data = data[data["PRDSPC_ID"] == SCHA_HAR_LUK_NARA_DAEU[0]]
SCHA_HAR_LUK_NARA_DAEU_data.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO  \
# 98   1173DK    22G12251111  2022G12251   22G12251111   HBV141770
# 114  1173DK  22G12C191111A  2022G12C19   22G12C19111   HBB085250
# 115  1173DK  22G12C191121A  2022G12C19   22G12C19112   HBB085250
# 116  1173DK  22G12C191131A  2022G12C19   22G12C19113   HBB085250
# 117  1173DK    22G12C80111  2022G12C80   22G12C80111  HBF178160B
#
#          MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 98     22G12251111     1.0  1282N     1282N    NaN  ...   1065A       0
# 114  22G12C191111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 115  22G12C191121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 116  22G12C191131A     1.0  1282N     1282N    NaN  ...   1065A       0
# 117    22G12C80111     1.0  1282N     1282N    NaN  ...   1065A       0
#
#                  CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %% [markdown]
# ### ANN 0차

# %%
SCHA_HAR_LUK_NARA_DAEU_data_ANN0 = SCHA_HAR_LUK_NARA_DAEU_data[SCHA_HAR_LUK_NARA_DAEU_data["PNSPRC_CD"] == "AN10"]
SCHA_HAR_LUK_NARA_DAEU_data_ANN0.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 98   1173DK  22G12251111  2022G12251   22G12251111   HBV141770  22G12251111
# 263  1173DK  22H12093111  2022H12093   22H12093111   HBF178110  22H12093111
# 264  1173DK  22H12094111  2022H12094   22H12094111   HBB085340  22H12094111
# 265  1173DK  22H12095111  2022H12095   22H12095111  HBB085140A  22H12095111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 98      1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-28 10:19:23
# 263     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-11 10:18:49
# 264     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-11 10:20:02
# 265     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-11 10:20:34
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 98  2022-08-31 06:32:49        NaT        NaN        NaN  1055A         E
# ...

# %%
SCHA_HAR_LUK_NARA_DAEU_data_ANN0_size = len(SCHA_HAR_LUK_NARA_DAEU_data_ANN0)
SCHA_HAR_LUK_NARA_DAEU_data_ANN0_size
# Out:
# 4

# %% [markdown]
# ### ANN 1차 이상

# %%
SCHA_HAR_LUK_NARA_DAEU_data_ANN1 = SCHA_HAR_LUK_NARA_DAEU_data[SCHA_HAR_LUK_NARA_DAEU_data["PNSPRC_CD"] != "AN10"]
SCHA_HAR_LUK_NARA_DAEU_data_ANN1.head()
# Out:
#      BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO  \
# 114  1173DK  22G12C191111A  2022G12C19   22G12C19111   HBB085250
# 115  1173DK  22G12C191121A  2022G12C19   22G12C19112   HBB085250
# 116  1173DK  22G12C191131A  2022G12C19   22G12C19113   HBB085250
# 117  1173DK    22G12C80111  2022G12C80   22G12C80111  HBF178160B
# 118  1173DK    22G12C80112  2022G12C80   22G12C80112  HBF178160B
#
#          MOTCOI_NO  TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT  \
# 114  22G12C191111A     1.0  1282N     1282N    NaN  ...   1065A       0
# 115  22G12C191121A     1.0  1282N     1282N    NaN  ...   1065A       0
# 116  22G12C191131A     1.0  1282N     1282N    NaN  ...   1065A       0
# 117    22G12C80111     1.0  1282N     1282N    NaN  ...   1065A       0
# 118    22G12C80112     1.0  1282N     1282N    NaN  ...   1065A       0
#
#                  CRT_DT              UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD  \
# ...

# %%
SCHA_HAR_LUK_NARA_DAEU_data_ANN1_size = len(SCHA_HAR_LUK_NARA_DAEU_data_ANN1)
SCHA_HAR_LUK_NARA_DAEU_data_ANN1_size
# Out:
# 5

# %% [markdown]
# ## 시흥공장

# %%
Siheung = np.array(["SK강"])

# %%
Siheung_data = data[data["PRDSPC_ID"] == Siheung[0]]
Siheung_data.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## HANWA CO / .LTD

# %%
HANWA_LTD = np.array(["SK85"])

# %%
HANWA_LTD_data = data[data["PRDSPC_ID"] == HANWA_LTD[0]]
HANWA_LTD_data.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 49   1173DK  22F13047111  2022F13047   22F13047111   HBB097210  22F13047111
# 50   1173DK  22F13051112  2022F13051   22F13051112   HBZ101910  22F13051112
# 121  1173DK  22G13015111  2022G13015   22G13015111   HBC144210  22G13015111
# 122  1173DK  22G13020111  2022G13020   22G13020111   HBD086240  22G13020111
# 356  1173DK  22H13007112  2022H13007   22H13007112  HBG136850A  22H13007112
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 49      1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-23 14:45:18
# 50      1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-24 15:35:16
# 121     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-05 17:14:05
# 122     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-06 09:31:31
# 356     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-08 09:18:27
#
# ...

# %% [markdown]
# ### ANN 0차

# %%
HANWA_LTD_data_data_ANN0 = HANWA_LTD_data[HANWA_LTD_data["PNSPRC_CD"] == "AN10"]
HANWA_LTD_data_data_ANN0.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 356  1173DK  22H13007112  2022H13007   22H13007112  HBG136850A  22H13007112
# 357  1173DK  22H13007113  2022H13007   22H13007113  HBG137430C  22H13007113
# 358  1173DK  22H13007114  2022H13007   22H13007114  HBG136830A  22H13007114
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 356     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-08 09:18:27
# 357     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-08 09:18:27
# 358     1.0  1282N     1282N    NaN  ...   1065A       0 2022-08-08 09:18:27
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 356 2022-09-02 20:14:01        NaT        NaN        NaN    NaN         L
# 357 2022-09-02 20:14:00        NaT        NaN        NaN    NaN         L
# 358 2022-09-02 20:14:01        NaT        NaN        NaN    NaN         L
#
#      ZON_CD
# 356   1510P
# 357   1510P
# ...

# %%
HANWA_LTD_data_data_ANN0_size = len(HANWA_LTD_data_data_ANN0)
HANWA_LTD_data_data_ANN0_size
# Out:
# 3

# %% [markdown]
# ### ANN 1차 이상

# %%
HANWA_LTD_data_data_ANN1 = HANWA_LTD_data[HANWA_LTD_data["PNSPRC_CD"] != "AN10"]
HANWA_LTD_data_data_ANN1.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 49   1173DK  22F13047111  2022F13047   22F13047111  HBB097210  22F13047111
# 50   1173DK  22F13051112  2022F13051   22F13051112  HBZ101910  22F13051112
# 121  1173DK  22G13015111  2022G13015   22G13015111  HBC144210  22G13015111
# 122  1173DK  22G13020111  2022G13020   22G13020111  HBD086240  22G13020111
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 49      1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-23 14:45:18
# 50      1.0  1282N     1282N    NaN  ...   1065A       0 2022-06-24 15:35:16
# 121     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-05 17:14:05
# 122     1.0  1282N     1282N    NaN  ...   1065A       0 2022-07-06 09:31:31
#
#                  UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 49  2022-09-03 05:08:30        NaT        NaN        NaN  1055A         E
# ...

# %%
HANWA_LTD_data_data_ANN1_size = len(HANWA_LTD_data_data_ANN1)
HANWA_LTD_data_data_ANN1_size
# Out:
# 4

# %% [markdown]
# ## (주)지에스앤티 / 한국엔에스케이

# %%
GSNT_HKNSK = np.array(["100CR6","100CR6-PA","SUJ2","SAE52100"])

# %%
GSNT_HKNSK_data = data[(data["PRDSPC_ID"] == GSNT_HKNSK[0])| (data["PRDSPC_ID"] == GSNT_HKNSK[1]) | (data["PRDSPC_ID"] == GSNT_HKNSK[2]) | (data["PRDSPC_ID"] == GSNT_HKNSK[3])]
GSNT_HKNSK_data.head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO MOTCOI_NO  \
# 393  1173DK  22J13014111  2022J13014   22J13014111  HBQ176480       NaN
# 394  1173DK  22J13014112  2022J13014   22J13014112  HBQ176460       NaN
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 393     1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-13 11:23:05
# 394     1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-13 11:23:05
#
#     UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  ZON_CD
# 393    NaT        NaT        NaN        NaN  1055E         E   1510P
# 394    NaT        NaT        NaN        NaN  1055E         E   1510P
#
# [2 rows x 113 columns]

# %% [markdown]
# ### ANN 0차

# %%
GSNT_HKNSK_data_ANN0 = GSNT_HKNSK_data[GSNT_HKNSK_data["PNSPRC_CD"] == "AN10"]
GSNT_HKNSK_data_ANN0 .head()
# Out:
#      BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO MOTCOI_NO  \
# 393  1173DK  22J13014111  2022J13014   22J13014111  HBQ176480       NaN
# 394  1173DK  22J13014112  2022J13014   22J13014112  HBQ176460       NaN
#
#      TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 393     1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-13 11:23:05
# 394     1.0  1282N     1282N    NaN  ...   1065A       0 2022-09-13 11:23:05
#
#     UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  ZON_CD
# 393    NaT        NaT        NaN        NaN  1055E         E   1510P
# 394    NaT        NaT        NaN        NaN  1055E         E   1510P
#
# [2 rows x 113 columns]

# %%
GSNT_HKNSK_data_ANN0_size = len(GSNT_HKNSK_data_ANN0)
GSNT_HKNSK_data_ANN0_size
# Out:
# 2

# %% [markdown]
# ### ANN 1차 이상

# %%
GSNT_HKNSK_data_ANN1 = GSNT_HKNSK_data[GSNT_HKNSK_data["PNSPRC_CD"] != "AN10"]
GSNT_HKNSK_data_ANN1 .head()
# Out:
# Empty DataFrame
# ...

# %%
GSNT_HKNSK_data_ANN1_size = len(GSNT_HKNSK_data_ANN1)
GSNT_HKNSK_data_ANN1_size
# Out:
# 0

# %% [markdown]
# ## (주)아스픽 / (주)엠알인프라오토

# %%
ASPIC_MR = np.array(["AISI4140M-S"])

# %%
ASPIC_MR_data = data[data["PRDSPC_ID"] == ASPIC_MR[0]]
ASPIC_MR_data.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## 유신정밀공업(주) / (주)화진금속

# %%
USIN_HJ = np.array(["50CRV4M-S"])

# %%
USIN_HJ_data = data[data["PRDSPC_ID"] == USIN_HJ[0]]
USIN_HJ_data.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 6   1173DK  21M12D061111A  2021M12D06   21M12D06111   HBY122970  21M12D06111
# 94  1173DK    22G12242111  2022G12242   22G12242111  HBF136990C  22G12242111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 6      1.0  1282S     1282S    NaN  ...   1065A       0 2022-09-01 16:47:55
# 94     1.0  1282Y     1282Y    NaN  ...   1065A       0 2022-07-27 13:19:17
#
#                 UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 6  2022-09-03 09:11:31        NaT        NaN        NaN  1055A         E
# 94 2022-09-03 13:07:05        NaT        NaN        NaN  1055A         E
#
#     ZON_CD
# 6    1510P
# 94   1510P
#
# [2 rows x 113 columns]

# %% [markdown]
# ### ANN 0차

# %%
USIN_HJ_data_ANN0 = USIN_HJ_data[USIN_HJ_data["PNSPRC_CD"] == "AN10"]
USIN_HJ_data_ANN0.head()
# Out:
#    BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 6  1173DK  21M12D061111A  2021M12D06   21M12D06111  HBY122970  21M12D06111
#
#    TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 6     1.0  1282S     1282S    NaN  ...   1065A       0 2022-09-01 16:47:55
#
#                UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 6 2022-09-03 09:11:31        NaT        NaN        NaN  1055A         E
#
#    ZON_CD
# 6   1510P
#
# [1 rows x 113 columns]

# %%
USIN_HJ_data_ANN0_size = len(USIN_HJ_data_ANN0)
USIN_HJ_data_ANN0_size
# Out:
# 1

# %% [markdown]
# ### ANN 1차 이상

# %%
USIN_HJ_data_ANN1 = USIN_HJ_data[USIN_HJ_data["PNSPRC_CD"] != "AN10"]
USIN_HJ_data_ANN1.head()
# Out:
#     BUS_CD      COIL_NO      LOT_NO BASIC_COIL_NO   HOTCOI_NO    MOTCOI_NO  \
# 94  1173DK  22G12242111  2022G12242   22G12242111  HBF136990C  22G12242111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 94     1.0  1282Y     1282Y    NaN  ...   1065A       0 2022-07-27 13:19:17
#
#                 UPD_DT COILEND_DT SEMIPKG_YN SEMIPKG_CD PKG_CD LEV2SE_YN  \
# 94 2022-09-03 13:07:05        NaT        NaN        NaN  1055A         E
#
#     ZON_CD
# 94   1510P
#
# [1 rows x 113 columns]

# %%
USIN_HJ_data_ANN1_size = len(USIN_HJ_data_ANN1)
USIN_HJ_data_ANN1_size
# Out:
# 1

# %% [markdown]
# ## 엔에스하이텍

# %%
NShitec = np.array(["S45CM-R"])

# %%
NShitec_data = data[data["PRDSPC_ID"] == NShitec[0]]
NShitec_data.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 77  1173DK  22G122021111A  2022G12202   22G12202111  CRW397701  22G12202111
# 78  1173DK  22G122021121A  2022G12202   22G12202112  CTX443601  22G12202112
# 79  1173DK  22G122022111A  2022G12202   22G12202211  CRW397701  22G12202111
# 80  1173DK  22G122022121A  2022G12202   22G12202212  CTX443601  22G12202112
# 81  1173DK  22G122023111A  2022G12202   22G12202311  CRW397701  22G12202111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 77   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 78   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 79   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 80   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 81   103.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
#
# ...

# %% [markdown]
# ### ANN 0차

# %%
NShitec_data_ANN0 = NShitec_data[NShitec_data["PNSPRC_CD"] == "AN10"]
NShitec_data_ANN0.head()
# Out:
# Empty DataFrame
# ...

# %%
NShitec_data_ANN0_size = len(NShitec_data_ANN0)
NShitec_data_ANN0_size
# Out:
# 0

# %% [markdown]
# ### ANN 1차 이상

# %%
NShitec_data_ANN1 = NShitec_data[NShitec_data["PNSPRC_CD"] != "AN10"]
NShitec_data_ANN1.head()
# Out:
#     BUS_CD        COIL_NO      LOT_NO BASIC_COIL_NO  HOTCOI_NO    MOTCOI_NO  \
# 77  1173DK  22G122021111A  2022G12202   22G12202111  CRW397701  22G12202111
# 78  1173DK  22G122021121A  2022G12202   22G12202112  CTX443601  22G12202112
# 79  1173DK  22G122022111A  2022G12202   22G12202211  CRW397701  22G12202111
# 80  1173DK  22G122022121A  2022G12202   22G12202212  CTX443601  22G12202112
# 81  1173DK  22G122023111A  2022G12202   22G12202311  CRW397701  22G12202111
#
#     TRK_NO EMG_CD AFTEMG_CD PKG_NO  ...  WRK_CD INP_WGT              CRT_DT  \
# 77   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 78   101.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 79   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
# 80   102.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 03:47:26
# 81   103.0  1282N     1282N    NaN  ...   1065A       0 2022-09-03 04:18:31
#
# ...

# %%
NShitec_data_ANN1_size = len(NShitec_data_ANN1)
NShitec_data_ANN1_size
# Out:
# 6

# %%
ANN0_size = [HKBOG_data_ANN0_size,ILJINNTS_2_data_ANN0_size,JMI_data_ANN0_size,JM_DS_GS_HJ_data_ANN0_size,
            NHK_data_ANN0_size,SCHAEFFLER_data_ANN0_size,SCHA_HAR_LUK_NARA_DAEU_data_ANN0_size,
            HANWA_LTD_data_data_ANN0_size,GSNT_HKNSK_data_ANN0_size,
            USIN_HJ_data_ANN0_size,NShitec_data_ANN0_size,]

# %%
len(ANN0_size)
# Out:
# 11

# %%
ANN1_size = [HKBOG_data_ANN1_size,ILJINNTS_2_data_ANN1_size,JMI_data_ANN1_size,JM_DS_GS_HJ_data_ANN1_size,
            NHK_data_ANN1_size,SCHAEFFLER_data_ANN12_size,SCHA_HAR_LUK_NARA_DAEU_data_ANN1_size,
            HANWA_LTD_data_data_ANN1_size,GSNT_HKNSK_data_ANN1_size,USIN_HJ_data_ANN1_size,NShitec_data_ANN1_size]

# %%
len(ANN1_size)
# Out:
# 11

# %%
Company = ["HKBOG", "ILJINNTS_2", "JMI", "JM_DS_GS_HJ", "NHK", "SCHAEFFLER", "SCHA_HAR_LUK_NARA_DAEU", "HANWA_LTD", "GSNT_HKNSK", "USIN_HJ", "NShitec"]

# %%
Product_Code = ["S45CM-R", "SK4M-R, SK5M-R, SKS51M-R, SKS81M-R", "SAE1074M-R", "S55CM-S, SCM435M-S, SK5M-S", "51CRV4M-S", "CK75M2/M3", "C80M", "SK85", "100CR6, 100CR6-PA, SUJ2, SAE52100", "50CRV4M-S", "S45CM-R"]

# %%
ANN0_degree = ["-", "750","700","725(표준)", "725 x MAX", "735 x 25", "735", "750 x MAX", "750 x MAX", "750", "750"]

# %%
ANN1_degree = ["620", "700(표준)","-","725", "700 x MAX", "720 x 25", "720", "700(표준)", "750 x MAX", "750", "-"]

# %% [markdown]
# ### ANN 재공 현황 DATA에 존재하는 Special Cycle
# ANN 0차와 ANN 1차 이상 둘 다 존재하지 않은 경우는 넣지 않았음
#
# SCHAEFFLER_GROUP은 ANN0/ ANN1~2/ ANN3차로 구분됨
# 현재 데이터에서 3차는 존재하지 않았으므로 제외시켰음

# %%
Special_Cycle_df = pd.DataFrame({"Company" : Company, 
                                "제품규격코드" : Product_Code,
                                "ANN 0차" : ANN0_size,
                                "ANN 1차 이상" : ANN1_size,
                                "ANN0_degree" : ANN0_degree,
                                "ANN1_degree" : ANN1_degree
                                })

Special_Cycle_df
# Out:
#                    Company                              제품규격코드  ANN 0차  \
# 0                    HKBOG                             S45CM-R       0
# 1               ILJINNTS_2  SK4M-R, SK5M-R, SKS51M-R, SKS81M-R       1
# 2                      JMI                          SAE1074M-R       1
# 3              JM_DS_GS_HJ          S55CM-S, SCM435M-S, SK5M-S       3
# 4                      NHK                           51CRV4M-S       6
# 5               SCHAEFFLER                           CK75M2/M3      10
# 6   SCHA_HAR_LUK_NARA_DAEU                                C80M       4
# 7                HANWA_LTD                                SK85       3
# 8               GSNT_HKNSK   100CR6, 100CR6-PA, SUJ2, SAE52100       2
# 9                  USIN_HJ                           50CRV4M-S       1
# 10                 NShitec                             S45CM-R       0
#
#     ANN 1차 이상 ANN0_degree ANN1_degree
# 0           6           -         620
# ...
