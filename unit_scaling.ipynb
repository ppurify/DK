# %%
import numpy as np
import pandas as pd

# %%
base_capacity_information = pd.read_csv("./data/base_capacity_information.csv")
base_capacity_information.head()
# Out:
#    Maker  Base_number  Weight(Ton)  Height(mm)  Outer_max(mm)  Outer_min(mm)  \
# 0  EBNER            1           35        2800           1700            900
# 1  EBNER            2           35        2800           1700            900
# 2  EBNER            3           35        2800           1700            900
# 3  EBNER            4           35        2800           1700            900
# 4  EBNER            5           35        2800           1700            900
#
#    Inner(mm)
# 0        508
# 1        508
# 2        508
# 3        508
# 4        508

# %%
data_df = pd.read_csv("./data/data_df.csv").drop("Unnamed: 0", axis = 1)
data_df.head()
# Out:
#          COIL_NO  PRDSPC_ID PNSPRC_CD cycle  WDT_LEN  WGT_WGT  IND_CD  \
# 0    09KA1B77311   SCP1-H-B      AN11   620    309.0     4811     508
# 1  21M12D061111A  50CRV4M-S      AN10   750    248.0     2091     508
# 2  22A122851111A    S55CM-R      AN10   725    410.0     5121     508
# 3  22A122852111A    S55CM-R      AN10   725    410.0     5121     508
# 4  22A122853111A    S55CM-R      AN10   725    210.0     2623     508
#
#    OUD_LEN  STL_CD EMG_CD                  고객사
# 0     1668   10021  1282N                  NaN
# 1     1275   10022  1282S  유신정밀공업(주) / (주)화진금속
# 2     1511   10022  1282N                  NaN
# 3     1511   10022  1282N                  NaN
# 4     1511   10022  1282N                  NaN

# %%
data_df['WGT_WGT'] = data_df['WGT_WGT']/1000

# %%
data_df.to_csv("./data/data_df.csv", sep=",", na_rep = "NaN")
